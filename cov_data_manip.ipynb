# %%
import pandas as pd
import geopandas as gpd

# %%
df = gpd.read_file(r"data\ncov_cases-11-24-2020.geojson")
df
# Out:
#      OBJECTID        Province_State Country_Region   Last_Update        Lat  \
# 0           1                  None    Afghanistan  1.606242e+12  33.939110
# 1           2                  None        Albania  1.606242e+12  41.153300
# 2           3                  None        Algeria  1.606242e+12  28.033900
# 3           4                  None        Andorra  1.606242e+12  42.506300
# 4           5                  None         Angola  1.606242e+12 -11.202700
# ..        ...                   ...            ...           ...        ...
# 756       757                  Ohio             US  1.606242e+12  40.388783
# 757       758               Alabama             US  1.606242e+12  32.318200
# 758       759        North Carolina             US  1.606242e+12  35.630066
# 759       760  District of Columbia             US  1.606242e+12  38.897438
# 760       761                 Maine             US  1.606242e+12  44.693947
#
# ...

# %% [markdown]
# ### Create new df with only US data

# %%
df2 = df[df.Country_Region == 'US']

# %%
df2
# Out:
#      OBJECTID                Province_State Country_Region   Last_Update  \
# 701       702                   Mississippi             US  1.606242e+12
# 702       703                Grand Princess             US  1.596508e+12
# 703       704                      Oklahoma             US  1.606242e+12
# 704       705                      Delaware             US  1.606242e+12
# 705       706                     Minnesota             US  1.606242e+12
# 706       707                      Illinois             US  1.606242e+12
# 707       708                      Arkansas             US  1.606242e+12
# 708       709                    New Mexico             US  1.606242e+12
# 709       710                       Indiana             US  1.606242e+12
# 710       711                     Louisiana             US  1.606242e+12
# 711       712                         Texas             US  1.606242e+12
# 712       713                     Wisconsin             US  1.606242e+12
# ...

# %% [markdown]
# ### Export parsed df as geojson

# %%
df2.to_file("data/ncov_cases_US-11-24-2020.geojson", driver='GeoJSON')
